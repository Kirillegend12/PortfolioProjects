# %%
# import libraries

from bs4 import BeautifulSoup
import requests
import csv

import time
import datetime

import smtplib

# %%
url =  'https://www.amazon.com/Analyst-Graduate-Career-Professional-Spreadsheet/dp/B0C1M17KKT/ref=sr_1_9?crid=3J8YU97W0JC4S&dib=eyJ2IjoiMSJ9.gvtBljKq2gIhlqJ1Acnrud0LvMJ-zHsYKMVn6OU6tqztR-PyvBUp9N7DM_qoxVAgbpnuW8Z-4zet-ASL115yADMnwge4tUrt2HLICQLRadhOpuNccQxjkA9jo5nSxQGUURon_0nZI_Y-Xa1g_6ppQFsS2nS3795H9SQ8MZ00IffCNsG1FLixnIf6WFutHd-0nz_cJsVTE2G56MMTHnhB523AkqkOKXtttmx9UgA5IVAZpnSH4FAT4unvNRSQkeWYBvKpgllSRlnmOl9gqRS-KR7_BlE0z3yCi_d-IfWbDJ8.iWlA4umxLxFVMgm3dWCOzJKdW91cgPOKQfJk92X2rqY&dib_tag=se&keywords=data%2B%2B%2Banalyst%2B%2B%2Btshirt&qid=1778947159&sprefix=data%2B%2B%2Banalyst%2B%2B%2Btshirt%2Caps%2C298&sr=8-9&th=1&psc=1'

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Connection": "keep-alive",
}

page = requests.get(url,headers = headers)

soup1 = BeautifulSoup(page.content, 'html.parser')

soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')

title = soup2.find(id='productTitle').get_text()

price = soup2.find(id = 'apex-pricetopay-accessibility-label').get_text()

print(title)
print(price)
# Out:
#                  Data Analyst T Shirt Funny Gift for Bean Counter Graduate Career Professional Numbers Geek Spreadsheet Unisex Tee
#
#
#                  PLN 116.87

# %%
price = price.replace('\xa0',' ').strip()[4:]

title = title.strip()

# %%
print(price)
print(title)
# Out:
# 116.87
# Data Analyst T Shirt Funny Gift for Bean Counter Graduate Career Professional Numbers Geek Spreadsheet Unisex Tee

# %%
today = datetime.date.today()

print(today)
# Out:
# 2026-05-17

# %%
# Creating the main version of the csv file with the headers (to be run once) 

header = ['Title', 'Price', 'Date']
data = [title, price, today]

with open('AmazonWebscraper.csv', 'w', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\Kiril\Python Notebooks\AmazonWebscraper.csv")

print(df)
# Out:
#                                                Title   Price        Date
# 0  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17

# %%
# Now we are apending data to csv 

with open('AmazonWebscraper.csv', 'a+', newline = '', encoding = 'UTF8') as f:
    writer = csv.writer(f)
    writer.writerow(data)

# %%
def check_price():

    # Making a connection to the Website for API call 
    
    url =  'https://www.amazon.com/Analyst-Graduate-Career-Professional-Spreadsheet/dp/B0C1M17KKT/ref=sr_1_9?crid=3J8YU97W0JC4S&dib=eyJ2IjoiMSJ9.gvtBljKq2gIhlqJ1Acnrud0LvMJ-zHsYKMVn6OU6tqztR-PyvBUp9N7DM_qoxVAgbpnuW8Z-4zet-ASL115yADMnwge4tUrt2HLICQLRadhOpuNccQxjkA9jo5nSxQGUURon_0nZI_Y-Xa1g_6ppQFsS2nS3795H9SQ8MZ00IffCNsG1FLixnIf6WFutHd-0nz_cJsVTE2G56MMTHnhB523AkqkOKXtttmx9UgA5IVAZpnSH4FAT4unvNRSQkeWYBvKpgllSRlnmOl9gqRS-KR7_BlE0z3yCi_d-IfWbDJ8.iWlA4umxLxFVMgm3dWCOzJKdW91cgPOKQfJk92X2rqY&dib_tag=se&keywords=data%2B%2B%2Banalyst%2B%2B%2Btshirt&qid=1778947159&sprefix=data%2B%2B%2Banalyst%2B%2B%2Btshirt%2Caps%2C298&sr=8-9&th=1&psc=1'

    headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0 Safari/537.36",
    "Accept-Language": "en-US,en;q=0.9",
    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Connection": "keep-alive",
    }
    page = requests.get(url,headers = headers)
    soup1 = BeautifulSoup(page.content, 'html.parser')
    soup2 = BeautifulSoup(soup1.prettify(), 'html.parser')
    title = soup2.find(id='productTitle').get_text()
    price = soup2.find(id = 'apex-pricetopay-accessibility-label').get_text()

    # Formating the Data 
    price = price.replace('\xa0',' ').strip()[4:]
    title = title.strip()

    #Adding today's date 
    today = datetime.date.today()

    # Creating values for Columns and Rows for the exporting into csv file 
    header = ['Title', 'Price', 'Date']
    data = [title, price, today]

    #Apending the file with the new information 
    with open('AmazonWebscraper.csv', 'a+', newline = '', encoding = 'UTF8') as f:
        writer = csv.writer(f)
        writer.writerow(data)

    if price <= 100:
        send_mail()

# %%
# Schedule extracting from the site into your csv file 

while True:
    check_price()
    time.sleep(5)

# %%
import pandas as pd 

df = pd.read_csv(r"C:\Users\Kiril\Python Notebooks\AmazonWebscraper.csv")

print(df)
# Out:
#                                                Title   Price        Date
# 0  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 1  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 2  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 3  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 4  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 5  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 6  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17
# 7  Data Analyst T Shirt Funny Gift for Bean Count...  116.87  2026-05-17

# %%
# Additional function to send you and email once something happens 

def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    server.ehlo()
    server.login('pav.kirill12@gmail.com','password')

    subject = 'The shirt you want to buy is below 100 PLN! Now is the chance to buy it'
    body = 'Kiril, this is the moment when you can buy a nice shirt in lower price'

    msg = f'Subject: {subject}\n\n{body}'


    server.sendmail('pav.kirill12@gmail.com',msg)
